# %%
import pandas as pd
df = pd.read_csv('dodag.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468060 entries, 0 to 468059
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   time                                 468060 non-null  float64
#  1   source                               468060 non-null  int64
#  2   destination                          468060 non-null  int64
#  3   length                               468060 non-null  float64
#  4   info                                 468060 non-null  float64
#  5   transmission_rate_per_1000_ms        468060 non-null  float64
#  6   reception_rate_per_1000_ms           468060 non-null  float64
#  7   transmission_average_per_sec         468060 non-null  float64
#  8   reception_average_per_sec            468060 non-null  float64
#  9   transmission_count_per_sec           468060 non-null  float64
#  10  reception_count_per_sec              468060 non-null  float64
#  11  transmission_total_duration_per_sec  468060 non-null  float64
#  12  reception_total_duration_per_sec     468060 non-null  float64
#  13  dao                                  468060 non-null  float64
#  14  dis                                  468060 non-null  float64
#  15  dio                                  468060 non-null  float64
#  16  category                             468060 non-null  object
#  17  label                                468060 non-null  int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 64.3+ MB

# %%
df.head()
# Out:
#     time  source  destination  length  info  transmission_rate_per_1000_ms  \
# 0  0.023       5         9999     0.0   0.0                       1.000000
# 1  0.024       8         9999     0.0   0.0                       0.776751
# 2  0.024       9         9999     0.0   0.0                       0.764212
# 3  0.024       1         9999     0.0   0.0                       0.755007
# 4  0.024      20         9999     0.0   0.0                       0.764212
#
#    reception_rate_per_1000_ms  transmission_average_per_sec  \
# 0                         1.0                      0.321947
# 1                         1.0                      0.308151
# 2                         1.0                      0.304484
# 3                         1.0                      0.336624
# 4                         1.0                      0.305202
#
#    reception_average_per_sec  transmission_count_per_sec  \
# 0                        0.0                    1.000000
# 1                        0.0                    0.776751
# 2                        0.0                    0.764212
# 3                        0.0                    0.755007
# 4                        0.0                    0.764212
#
#    reception_count_per_sec  transmission_total_duration_per_sec  \
# 0                      1.0                             0.416877
# 1                      1.0                             0.393983
# 2                      1.0                             0.374588
# 3                      1.0                             0.400598
# 4                      1.0                             0.381593
#
#    reception_total_duration_per_sec  dao  dis       dio category  label
# 0                               0.0  0.0  0.0  1.000000    Dodag      1
# 1                               0.0  0.0  0.0  0.776751    Dodag      1
# 2                               0.0  0.0  0.0  0.764212    Dodag      1
# 3                               0.0  0.0  0.0  0.755007    Dodag      1
# 4                               0.0  0.0  0.0  0.764212    Dodag      1

# %%
# Check if 'label' is in the columns
if 'label' in df.columns:
    print(df['label'].value_counts())
else:
    print("'label' column does not exist in the DataFrame.")
# Out:
# 0    297818
# 1    170242
# Name: label, dtype: int64

# %% [markdown]
# data preprocessing

# %%
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE  # Import t-SNE
import pandas as pd

# Assuming df is your DataFrame containing the dataset

# Instantiate StandardScaler
scalar = StandardScaler()

# Drop the 'category' column
X = df.drop(['label', 'category'], axis=1)  # Drop both the target variable and the categorical column
y = df['label']  # Target variable

# Store column names
column_names = X.columns.tolist()

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=23)  # Assuming 2 components for visualization
X_embedded = tsne.fit_transform(X)

# Split the embedded data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_embedded, y, test_size=0.2, random_state=23)

# Check value counts of 'label' column before undersampling
print("Value counts of 'label' column before undersampling:")
print(y_train.value_counts())

# Instantiate the random sampler for undersampling
undersampler = RandomUnderSampler(random_state=42)

# Balance only the training set
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# Check value counts of 'label' column after undersampling
print("\nValue counts of 'label' column after undersampling:")
print(pd.Series(y_train_resampled).value_counts())

# Scale the embedded data
X_scaled = scalar.fit_transform(X_embedded)

# Convert the scaled data back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=['TSNE_Component_1', 'TSNE_Component_2'])

# Display the first 10 rows of the scaled data
print("First 10 rows of the scaled data:")
print(X_scaled_df.head(10))
# Out:
# Value counts of 'label' column before undersampling:
# 0    238342
# 1    136106
# Name: label, dtype: int64
#
# Value counts of 'label' column after undersampling:
# 0    136106
# 1    136106
# Name: label, dtype: int64
# First 10 rows of the scaled data:
#    TSNE_Component_1  TSNE_Component_2
# 0         -2.114285         -0.239400
# 1         -1.818542          0.092354
# 2         -1.876355          0.144892
# 3         -1.771270         -1.146231
# 4         -1.619826          1.085242
# 5         -1.405761          0.391927
# 6         -2.114340         -0.239377
# 7         -1.619855          1.085285
# 8         -1.876303          0.144899
# 9         -1.818551          0.092359

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize KNN model
knn_model = KNeighborsClassifier()

# Train the model
knn_model.fit(X_train_resampled, y_train_resampled)

# Make predictions
y_pred_knn = knn_model.predict(X_test)

# %% [markdown]
# checking Accuracy

# %%
# Accuracy on the training set
train_accuracy = knn_model.score(X_train_resampled, y_train_resampled)
print("Training Accuracy:", train_accuracy)

# Accuracy on the test set
test_accuracy = knn_model.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9611369079981779
# Test Accuracy: 0.9362902192026663

# %%
import joblib
# Save the best model to disk
joblib.dump(knn_model, 'knn_dodag_model.pkl')
# Out:
# ['knn_dodag_model.pkl']

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns

# Make predictions using the best model
y_predict = knn_model.predict(X_test)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_predict, labels=[0, 1])

# Create DataFrame for confusion matrix
confusion = pd.DataFrame(conf_matrix, index=['is Normal', 'is dodag'], columns=['predicted normal', 'predicted dodag'])

# Visualize confusion matrix using heatmap
sns.heatmap(confusion, annot=True, fmt='d')

# Print classification report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95     59476
#            1       0.88      0.96      0.92     34136
#
#     accuracy                           0.94     93612
#    macro avg       0.93      0.94      0.93     93612
# weighted avg       0.94      0.94      0.94     93612

# %% [markdown]
# Correlation

# %%
import pandas as pd
import scipy.stats as stats

# Assuming your data is stored in a DataFrame called df
columns_of_interest = ['length', 'transmission_rate_per_1000_ms', 'reception_rate_per_1000_ms', 
                       'transmission_average_per_sec', 'reception_average_per_sec', 
                       'transmission_count_per_sec', 'reception_count_per_sec', 
                       'transmission_total_duration_per_sec', 'reception_total_duration_per_sec']

# Selecting only the numerical columns
numerical_data = df[columns_of_interest]

# Compute the Pearson correlation coefficient matrix
corr_matrix = numerical_data.corr()

# Display the correlation matrix
print(corr_matrix)
# Out:
#                                      length  transmission_rate_per_1000_ms  \
# length                                  NaN                            NaN
# transmission_rate_per_1000_ms           NaN                       1.000000
# reception_rate_per_1000_ms              NaN                       0.701718
# transmission_average_per_sec            NaN                      -0.075702
# reception_average_per_sec               NaN                      -0.514274
# transmission_count_per_sec              NaN                       0.999955
# reception_count_per_sec                 NaN                       0.701411
# transmission_total_duration_per_sec     NaN                      -0.012152
# reception_total_duration_per_sec        NaN                       0.039810
#
#                                      reception_rate_per_1000_ms  \
# length                                                      NaN
# transmission_rate_per_1000_ms                          0.701718
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                          -0.211073
# reception_average_per_sec                             -0.728187
# transmission_count_per_sec                             0.701925
# reception_count_per_sec                                0.999984
# transmission_total_duration_per_sec                    0.018044
# reception_total_duration_per_sec                       0.081233
#
#                                      transmission_average_per_sec  \
# length                                                        NaN
# transmission_rate_per_1000_ms                           -0.075702
# reception_rate_per_1000_ms                              -0.211073
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.356476
# transmission_count_per_sec                              -0.075968
# reception_count_per_sec                                 -0.211069
# transmission_total_duration_per_sec                      0.512783
# reception_total_duration_per_sec                         0.198984
#
#                                      reception_average_per_sec  \
# length                                                     NaN
# transmission_rate_per_1000_ms                        -0.514274
# reception_rate_per_1000_ms                           -0.728187
# transmission_average_per_sec                          0.356476
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                           -0.514606
# reception_count_per_sec                              -0.728378
# transmission_total_duration_per_sec                   0.209304
# reception_total_duration_per_sec                      0.367086
#
#                                      transmission_count_per_sec  \
# length                                                      NaN
# transmission_rate_per_1000_ms                          0.999955
# reception_rate_per_1000_ms                             0.701925
# transmission_average_per_sec                          -0.075968
# reception_average_per_sec                             -0.514606
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.701616
# transmission_total_duration_per_sec                   -0.012265
# reception_total_duration_per_sec                       0.039668
#
#                                      reception_count_per_sec  \
# length                                                   NaN
# transmission_rate_per_1000_ms                       0.701411
# reception_rate_per_1000_ms                          0.999984
# transmission_average_per_sec                       -0.211069
# reception_average_per_sec                          -0.728378
# transmission_count_per_sec                          0.701616
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                 0.018055
# reception_total_duration_per_sec                    0.081394
#
#                                      transmission_total_duration_per_sec  \
# length                                                               NaN
# transmission_rate_per_1000_ms                                  -0.012152
# reception_rate_per_1000_ms                                      0.018044
# transmission_average_per_sec                                    0.512783
# reception_average_per_sec                                       0.209304
# transmission_count_per_sec                                     -0.012265
# reception_count_per_sec                                         0.018055
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                                0.268627
#
#                                      reception_total_duration_per_sec
# length                                                            NaN
# transmission_rate_per_1000_ms                                0.039810
# reception_rate_per_1000_ms                                   0.081233
# transmission_average_per_sec                                 0.198984
# reception_average_per_sec                                    0.367086
# transmission_count_per_sec                                   0.039668
# reception_count_per_sec                                      0.081394
# transmission_total_duration_per_sec                          0.268627
# reception_total_duration_per_sec                             1.000000

# %%
# Compute the Spearman correlation coefficient matrix
spearman_corr_matrix = numerical_data.corr(method='spearman')

# Display the correlation matrix
print(spearman_corr_matrix)
# Out:
#                                      length  transmission_rate_per_1000_ms  \
# length                                  NaN                            NaN
# transmission_rate_per_1000_ms           NaN                       1.000000
# reception_rate_per_1000_ms              NaN                       0.739283
# transmission_average_per_sec            NaN                      -0.395605
# reception_average_per_sec               NaN                      -0.460590
# transmission_count_per_sec              NaN                       0.999895
# reception_count_per_sec                 NaN                       0.739189
# transmission_total_duration_per_sec     NaN                       0.039195
# reception_total_duration_per_sec        NaN                       0.087872
#
#                                      reception_rate_per_1000_ms  \
# length                                                      NaN
# transmission_rate_per_1000_ms                          0.739283
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                          -0.260852
# reception_average_per_sec                             -0.638541
# transmission_count_per_sec                             0.739309
# reception_count_per_sec                                0.999991
# transmission_total_duration_per_sec                    0.059816
# reception_total_duration_per_sec                       0.122638
#
#                                      transmission_average_per_sec  \
# length                                                        NaN
# transmission_rate_per_1000_ms                           -0.395605
# reception_rate_per_1000_ms                              -0.260852
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.481774
# transmission_count_per_sec                              -0.395521
# reception_count_per_sec                                 -0.261034
# transmission_total_duration_per_sec                      0.774797
# reception_total_duration_per_sec                         0.264399
#
#                                      reception_average_per_sec  \
# length                                                     NaN
# transmission_rate_per_1000_ms                        -0.460590
# reception_rate_per_1000_ms                           -0.638541
# transmission_average_per_sec                          0.481774
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                           -0.460790
# reception_count_per_sec                              -0.639075
# transmission_total_duration_per_sec                   0.306183
# reception_total_duration_per_sec                      0.395382
#
#                                      transmission_count_per_sec  \
# length                                                      NaN
# transmission_rate_per_1000_ms                          0.999895
# reception_rate_per_1000_ms                             0.739309
# transmission_average_per_sec                          -0.395521
# reception_average_per_sec                             -0.460790
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.739209
# transmission_total_duration_per_sec                    0.039274
# reception_total_duration_per_sec                       0.088590
#
#                                      reception_count_per_sec  \
# length                                                   NaN
# transmission_rate_per_1000_ms                       0.739189
# reception_rate_per_1000_ms                          0.999991
# transmission_average_per_sec                       -0.261034
# reception_average_per_sec                          -0.639075
# transmission_count_per_sec                          0.739209
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                 0.059622
# reception_total_duration_per_sec                    0.122386
#
#                                      transmission_total_duration_per_sec  \
# length                                                               NaN
# transmission_rate_per_1000_ms                                   0.039195
# reception_rate_per_1000_ms                                      0.059816
# transmission_average_per_sec                                    0.774797
# reception_average_per_sec                                       0.306183
# transmission_count_per_sec                                      0.039274
# reception_count_per_sec                                         0.059622
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                                0.348299
#
#                                      reception_total_duration_per_sec
# length                                                            NaN
# transmission_rate_per_1000_ms                                0.087872
# reception_rate_per_1000_ms                                   0.122638
# transmission_average_per_sec                                 0.264399
# reception_average_per_sec                                    0.395382
# transmission_count_per_sec                                   0.088590
# reception_count_per_sec                                      0.122386
# transmission_total_duration_per_sec                          0.348299
# reception_total_duration_per_sec                             1.000000

# %%
# Compute the Kendall tau correlation coefficient matrix
kendall_corr_matrix = numerical_data.corr(method='kendall')

# Display the correlation matrix
print(kendall_corr_matrix)
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py:5278: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
#                                      length  transmission_rate_per_1000_ms  \
# length                                  1.0                            NaN
# transmission_rate_per_1000_ms           NaN                       1.000000
# reception_rate_per_1000_ms              NaN                       0.565961
# transmission_average_per_sec            NaN                      -0.290993
# reception_average_per_sec               NaN                      -0.339383
# transmission_count_per_sec              NaN                       0.996020
# reception_count_per_sec                 NaN                       0.565866
# transmission_total_duration_per_sec     NaN                       0.027086
# reception_total_duration_per_sec        NaN                       0.071966
#
#                                      reception_rate_per_1000_ms  \
# length                                                      NaN
# transmission_rate_per_1000_ms                          0.565961
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                          -0.181930
# reception_average_per_sec                             -0.559171
# transmission_count_per_sec                             0.565999
# reception_count_per_sec                                0.998715
# transmission_total_duration_per_sec                    0.040930
# reception_total_duration_per_sec                       0.100240
#
#                                      transmission_average_per_sec  \
# length                                                        NaN
# transmission_rate_per_1000_ms                           -0.290993
# reception_rate_per_1000_ms                              -0.181930
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.348942
# transmission_count_per_sec                              -0.290974
# reception_count_per_sec                                 -0.182050
# transmission_total_duration_per_sec                      0.607998
# reception_total_duration_per_sec                         0.215976
#
#                                      reception_average_per_sec  \
# length                                                     NaN
# transmission_rate_per_1000_ms                        -0.339383
# reception_rate_per_1000_ms                           -0.559171
# transmission_average_per_sec                          0.348942
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                           -0.339704
# reception_count_per_sec                              -0.559366
# transmission_total_duration_per_sec                   0.208087
# reception_total_duration_per_sec                      0.323144
#
#                                      transmission_count_per_sec  \
# length                                                      NaN
# transmission_rate_per_1000_ms                          0.996020
# reception_rate_per_1000_ms                             0.565999
# transmission_average_per_sec                          -0.290974
# reception_average_per_sec                             -0.339704
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.565896
# transmission_total_duration_per_sec                    0.027137
# reception_total_duration_per_sec                       0.072551
#
#                                      reception_count_per_sec  \
# length                                                   NaN
# transmission_rate_per_1000_ms                       0.565866
# reception_rate_per_1000_ms                          0.998715
# transmission_average_per_sec                       -0.182050
# reception_average_per_sec                          -0.559366
# transmission_count_per_sec                          0.565896
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                 0.040795
# reception_total_duration_per_sec                    0.100033
#
#                                      transmission_total_duration_per_sec  \
# length                                                               NaN
# transmission_rate_per_1000_ms                                   0.027086
# reception_rate_per_1000_ms                                      0.040930
# transmission_average_per_sec                                    0.607998
# reception_average_per_sec                                       0.208087
# transmission_count_per_sec                                      0.027137
# reception_count_per_sec                                         0.040795
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                                0.288001
#
#                                      reception_total_duration_per_sec
# length                                                            NaN
# transmission_rate_per_1000_ms                                0.071966
# reception_rate_per_1000_ms                                   0.100240
# transmission_average_per_sec                                 0.215976
# reception_average_per_sec                                    0.323144
# transmission_count_per_sec                                   0.072551
# reception_count_per_sec                                      0.100033
# transmission_total_duration_per_sec                          0.288001
# reception_total_duration_per_sec                             1.000000

# %%
import numpy as np

# Compute the correlation coefficient matrix
corr_matrix = np.corrcoef(numerical_data, rowvar=False)

# Display the correlation matrix
print(corr_matrix)
# Out:
# [[        nan         nan         nan         nan         nan         nan
#           nan         nan         nan]
#  [        nan  1.          0.70171759 -0.07570201 -0.51427399  0.99995528
#    0.70141126 -0.0121519   0.03980954]
#  [        nan  0.70171759  1.         -0.21107282 -0.72818662  0.70192539
#    0.99998368  0.01804408  0.08123276]
#  [        nan -0.07570201 -0.21107282  1.          0.35647624 -0.07596794
#   -0.21106933  0.51278314  0.1989839 ]
#  [        nan -0.51427399 -0.72818662  0.35647624  1.         -0.51460635
#   -0.72837796  0.20930381  0.36708612]
#  [        nan  0.99995528  0.70192539 -0.07596794 -0.51460635  1.
#    0.70161615 -0.01226509  0.03966844]
#  [        nan  0.70141126  0.99998368 -0.21106933 -0.72837796  0.70161615
#    1.          0.01805492  0.08139446]
#  [        nan -0.0121519   0.01804408  0.51278314  0.20930381 -0.01226509
#    0.01805492  1.          0.26862693]
#  [        nan  0.03980954  0.08123276  0.1989839   0.36708612  0.03966844
#    0.08139446  0.26862693  1.        ]]
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
import pandas as pd
corr_coefficient = df['length'].corr(df['transmission_rate_per_1000_ms'])
print("Correlation coefficient between column1 and column2:", corr_coefficient)
# Out:
# Correlation coefficient between column1 and column2: nan

# %%
spearman_corr = df['length'].corr(df['transmission_rate_per_1000_ms'], method='spearman')

kendall_corr = df['length'].corr(df['transmission_rate_per_1000_ms'], method='kendall')

print("Spearman correlation coefficient:", spearman_corr)
print("Kendall correlation coefficient:", kendall_corr)
# Out:
# Spearman correlation coefficient: nan
# Kendall correlation coefficient: nan
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py:4916: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

print(correlation_matrix)
# Out:
#                                          time    source  destination  length  \
# time                                 1.000000  0.021715          NaN     NaN
# source                               0.021715  1.000000          NaN     NaN
# destination                               NaN       NaN          NaN     NaN
# length                                    NaN       NaN          NaN     NaN
# info                                      NaN       NaN          NaN     NaN
# transmission_rate_per_1000_ms       -0.583407 -0.131720          NaN     NaN
# reception_rate_per_1000_ms          -0.605838 -0.020855          NaN     NaN
# transmission_average_per_sec         0.263733 -0.028044          NaN     NaN
# reception_average_per_sec            0.679549  0.021373          NaN     NaN
# transmission_count_per_sec          -0.584171 -0.131620          NaN     NaN
# reception_count_per_sec             -0.605443 -0.020857          NaN     NaN
# transmission_total_duration_per_sec  0.136769  0.072429          NaN     NaN
# reception_total_duration_per_sec     0.198787 -0.006345          NaN     NaN
# dao                                       NaN       NaN          NaN     NaN
# dis                                       NaN       NaN          NaN     NaN
# dio                                 -0.583930 -0.131705          NaN     NaN
# label                                0.032135 -0.039922          NaN     NaN
#
#                                      info  transmission_rate_per_1000_ms  \
# time                                  NaN                      -0.583407
# source                                NaN                      -0.131720
# destination                           NaN                            NaN
# length                                NaN                            NaN
# info                                  NaN                            NaN
# transmission_rate_per_1000_ms         NaN                       1.000000
# reception_rate_per_1000_ms            NaN                       0.701718
# transmission_average_per_sec          NaN                      -0.075702
# reception_average_per_sec             NaN                      -0.514274
# transmission_count_per_sec            NaN                       0.999955
# reception_count_per_sec               NaN                       0.701411
# transmission_total_duration_per_sec   NaN                      -0.012152
# reception_total_duration_per_sec      NaN                       0.039810
# dao                                   NaN                            NaN
# dis                                   NaN                            NaN
# dio                                   NaN                       0.999958
# label                                 NaN                       0.147692
#
#                                      reception_rate_per_1000_ms  \
# time                                                  -0.605838
# source                                                -0.020855
# destination                                                 NaN
# length                                                      NaN
# info                                                        NaN
# transmission_rate_per_1000_ms                          0.701718
# reception_rate_per_1000_ms                             1.000000
# transmission_average_per_sec                          -0.211073
# reception_average_per_sec                             -0.728187
# transmission_count_per_sec                             0.701925
# reception_count_per_sec                                0.999984
# transmission_total_duration_per_sec                    0.018044
# reception_total_duration_per_sec                       0.081233
# dao                                                         NaN
# dis                                                         NaN
# dio                                                    0.701982
# label                                                  0.204579
#
#                                      transmission_average_per_sec  \
# time                                                     0.263733
# source                                                  -0.028044
# destination                                                   NaN
# length                                                        NaN
# info                                                          NaN
# transmission_rate_per_1000_ms                           -0.075702
# reception_rate_per_1000_ms                              -0.211073
# transmission_average_per_sec                             1.000000
# reception_average_per_sec                                0.356476
# transmission_count_per_sec                              -0.075968
# reception_count_per_sec                                 -0.211069
# transmission_total_duration_per_sec                      0.512783
# reception_total_duration_per_sec                         0.198984
# dao                                                           NaN
# dis                                                           NaN
# dio                                                     -0.076471
# label                                                   -0.006918
#
#                                      reception_average_per_sec  \
# time                                                  0.679549
# source                                                0.021373
# destination                                                NaN
# length                                                     NaN
# info                                                       NaN
# transmission_rate_per_1000_ms                        -0.514274
# reception_rate_per_1000_ms                           -0.728187
# transmission_average_per_sec                          0.356476
# reception_average_per_sec                             1.000000
# transmission_count_per_sec                           -0.514606
# reception_count_per_sec                              -0.728378
# transmission_total_duration_per_sec                   0.209304
# reception_total_duration_per_sec                      0.367086
# dao                                                        NaN
# dis                                                        NaN
# dio                                                  -0.514422
# label                                                 0.090162
#
#                                      transmission_count_per_sec  \
# time                                                  -0.584171
# source                                                -0.131620
# destination                                                 NaN
# length                                                      NaN
# info                                                        NaN
# transmission_rate_per_1000_ms                          0.999955
# reception_rate_per_1000_ms                             0.701925
# transmission_average_per_sec                          -0.075968
# reception_average_per_sec                             -0.514606
# transmission_count_per_sec                             1.000000
# reception_count_per_sec                                0.701616
# transmission_total_duration_per_sec                   -0.012265
# reception_total_duration_per_sec                       0.039668
# dao                                                         NaN
# dis                                                         NaN
# dio                                                    0.999995
# label                                                  0.146706
#
#                                      reception_count_per_sec  \
# time                                               -0.605443
# source                                             -0.020857
# destination                                              NaN
# length                                                   NaN
# info                                                     NaN
# transmission_rate_per_1000_ms                       0.701411
# reception_rate_per_1000_ms                          0.999984
# transmission_average_per_sec                       -0.211069
# reception_average_per_sec                          -0.728378
# transmission_count_per_sec                          0.701616
# reception_count_per_sec                             1.000000
# transmission_total_duration_per_sec                 0.018055
# reception_total_duration_per_sec                    0.081394
# dao                                                      NaN
# dis                                                      NaN
# dio                                                 0.701674
# label                                               0.204734
#
#                                      transmission_total_duration_per_sec  \
# time                                                            0.136769
# source                                                          0.072429
# destination                                                          NaN
# length                                                               NaN
# info                                                                 NaN
# transmission_rate_per_1000_ms                                  -0.012152
# reception_rate_per_1000_ms                                      0.018044
# transmission_average_per_sec                                    0.512783
# reception_average_per_sec                                       0.209304
# transmission_count_per_sec                                     -0.012265
# reception_count_per_sec                                         0.018055
# transmission_total_duration_per_sec                             1.000000
# reception_total_duration_per_sec                                0.268627
# dao                                                                  NaN
# dis                                                                  NaN
# dio                                                            -0.012159
# label                                                           0.060239
#
#                                      reception_total_duration_per_sec  dao  \
# time                                                         0.198787  NaN
# source                                                      -0.006345  NaN
# destination                                                       NaN  NaN
# length                                                            NaN  NaN
# info                                                              NaN  NaN
# transmission_rate_per_1000_ms                                0.039810  NaN
# reception_rate_per_1000_ms                                   0.081233  NaN
# transmission_average_per_sec                                 0.198984  NaN
# reception_average_per_sec                                    0.367086  NaN
# transmission_count_per_sec                                   0.039668  NaN
# reception_count_per_sec                                      0.081394  NaN
# transmission_total_duration_per_sec                          0.268627  NaN
# reception_total_duration_per_sec                             1.000000  NaN
# dao                                                               NaN  NaN
# dis                                                               NaN  NaN
# dio                                                          0.040071  NaN
# label                                                        0.511707  NaN
#
#                                      dis       dio     label
# time                                 NaN -0.583930  0.032135
# source                               NaN -0.131705 -0.039922
# destination                          NaN       NaN       NaN
# length                               NaN       NaN       NaN
# info                                 NaN       NaN       NaN
# transmission_rate_per_1000_ms        NaN  0.999958  0.147692
# reception_rate_per_1000_ms           NaN  0.701982  0.204579
# transmission_average_per_sec         NaN -0.076471 -0.006918
# reception_average_per_sec            NaN -0.514422  0.090162
# transmission_count_per_sec           NaN  0.999995  0.146706
# reception_count_per_sec              NaN  0.701674  0.204734
# transmission_total_duration_per_sec  NaN -0.012159  0.060239
# reception_total_duration_per_sec     NaN  0.040071  0.511707
# dao                                  NaN       NaN       NaN
# dis                                  NaN       NaN       NaN
# dio                                  NaN  1.000000  0.147458
# label                                NaN  0.147458  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
plt.title('Correlation Matrix')
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.show()
